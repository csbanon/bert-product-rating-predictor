# %% [markdown]
# <a href="https://colab.research.google.com/github/csbanon/bert-product-rating-predictor/blob/master/Star_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/99/84/7bc03215279f603125d844bf81c3fb3f2d50fe8e511546eb4897e4be2067/transformers-4.0.0-py3-none-any.whl (1.4MB)
#      |████████████████████████████████| 1.4MB 8.4MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 35.5MB/s
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 38.5MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.11.8)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=0adc5b86c40d98fa2718972ebebeff97d6e8f4068fddfa386f23fdcc73fea7f9
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.0.0

# %%
import glob
import numpy as np
import os
import pandas as pd
import sys
import torch
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, BertModel, BertForSequenceClassification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Get Preprocessed Review Data

# %%
github_url = 'https://raw.githubusercontent.com/csbanon/bert-product-rating-predictor/master/data/reviews_comments_stars.csv'
df = pd.read_csv(github_url)
df = df[['comment', 'stars']]
df
# Out:
#                                                   comment  stars
# 0       I could sit here and write all about the specs...      5
# 1       A very reasonably priced laptop for basic comp...      4
# 2       This is the best laptop deal you can get, full...      5
# 3       A few months after the purchase....It is still...      5
# 4       BUYER BE AWARE: This computer has Microsoft 10...      1
# ...                                                   ...    ...
# 195760  I have not tried this camera without the SD ca...      5
# 195761  Hello, I bought this item months ago and I tho...      1
# 195762  This is an incredible camera for the money!!  ...      5
# 195763  Great cameras. Purchased some for my mother af...      5
# 195764  Just getting it set up and seem s to work well...      5
#
# [195765 rows x 2 columns]

# %% [markdown]
# ## Define the neural model for fine tuning
# Given a review as an input sequence, we want to predict its star rating. This is a multi-class sequence classification task.
#
# For out model, we will use BertForSequenceClassification and set the num_labels argument to the number of unique values for Amazon star ratings.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels = len(df['stars'].unique()), # number of unique labels for our multi-class classification problem
    output_attentions = False,
    output_hidden_states = False,
)
model.to(device)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
# )

# %% [markdown]
# ## Define the Reviews Dataset
# Each item in the dataset will return a dictionary consisting of:
#
#
# *   input_ids: the input token ids
# *   attn_mask: the attention mask of the input sequence
# *   label: the target star rating of the input review

# %%
class ReviewsDataset(Dataset):
    def __init__(self, df, max_length=512):
        self.df = df
        self.tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
        self.max_length = max_length 
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        # input=review, label=stars
        review = self.df.loc[idx, 'comment']
        # labels are 0-indexed
        label = int(self.df.loc[idx, 'stars']) - 1
        
        encoded = self.tokenizer(
            review,                      # review to encode
            add_special_tokens=True,
            max_length=self.max_length,  # Truncate all segments to max_length
            padding='max_length',        # pad all reviews with the [PAD] token to the max_length
            return_attention_mask=True,  # Construct attention masks.
            truncation=True
        )
        
        input_ids = encoded['input_ids']
        attn_mask = encoded['attention_mask']
        
        return {
            'input_ids': torch.tensor(input_ids),
            'attn_mask': torch.tensor(attn_mask), 
            'label': torch.tensor(label)
        }

# %%
train_dataset, test_dataset = train_test_split(df, test_size=0.2, random_state=1)

# %%
test_dataset[:100].to_csv('/content/drive/My Drive/BERT project/gold.csv')

# %% [markdown]
# Define some constants that are important later on.

# %%
MAX_LEN = 256
TEST_SIZE = 0.2
VAL_SIZE = 0.125
TRAIN_BATCH_SIZE = 32
TEST_BATCH_SIZE = 32

CHECKPOINT_FILE = 'checkpoint.dat'
CHECKPOINT_FOLDER = 'Checkpoint'
EPOCHS = 4
LEARNING_RATE = 2e-05
PROJECT_FOLDER = '/content/drive/My Drive/BERT project/'
MODEL_FOLDER = 'Model_V3'
SAVE_EVERY = 100
NUM_WORKERS = 4

# %% [markdown]
# ## Create Datasets / DataLoaders
# Create the train and test datasets and dataloaders for the neural network.

# %%
train_dataset, test_dataset = train_test_split(df, test_size=TEST_SIZE, random_state=1)
train_dataset, val_dataset = train_test_split(train_dataset, test_size=VAL_SIZE, random_state=1)

train_dataset = train_dataset.reset_index(drop=True)
val_dataset = val_dataset.reset_index(drop=True)
test_dataset = test_dataset.reset_index(drop=True)

train_set = ReviewsDataset(train_dataset, MAX_LEN)
val_set = ReviewsDataset(val_dataset, MAX_LEN)
test_set = ReviewsDataset(test_dataset, MAX_LEN)

print("# of samples in train set: {}".format(len(train_set)))
print("# of samples in val set: {}".format(len(val_set)))
print("# of samples in test set: {}".format(len(test_set)))
# Out:
# # of samples in train set: 137035
# # of samples in val set: 19577
# # of samples in test set: 39153

# %%
train_params = {
                'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': NUM_WORKERS
                }
val_params = train_params

test_params = {
                'batch_size': TEST_BATCH_SIZE,
                'shuffle': False,
                'num_workers': NUM_WORKERS
              }

train_loader = DataLoader(train_set, **train_params)
val_loader = DataLoader(val_set, **val_params)
test_loader = DataLoader(test_set, **test_params)

# %% [markdown]
# ## Define the neural model for fine tuning
# Given a review as an input sequence, we want to predict its star rating. This is a multi-class sequence classification task.
#
# For out model, we will use BertForSequenceClassification and set the num_labels argument to the number of unique values for Amazon star ratings.

# %% [markdown]
# ## Fine Tuning the Model on Train Dataset

# %%
# For weighted Cross Entropy Loss
# Penalize errors higher if they come from a class with lower frequency
star_groups = df.groupby('stars')
star_distribution = []
for i in range(len(df['stars'].unique())):
    star_distribution.append(len(star_groups.groups[i+1])/len(df))

star_distribution = torch.tensor(star_distribution, dtype=torch.float32)

# V3
weights = 1.0 / star_distribution
weights = weights / weights.sum()

# V4
# weights = 1.0 - star_distribution

print('{:<20}: {}'.format('Star distribution', star_distribution.tolist()))
print('{:<20}: {}'.format('Weights', weights.tolist()))
# Out:
# Star distribution   : [0.09381656348705292, 0.04584067687392235, 0.05710418149828911, 0.11441779881715775, 0.6888207793235779]
# Weights             : [0.17712825536727905, 0.3625069260597229, 0.29100432991981506, 0.1452358216047287, 0.02412465587258339]

# %%
# Define the optimizer
loss_function = torch.nn.CrossEntropyLoss(weight=weights.to(device), reduction='mean')
optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %%
# Define the accuracy function
def calculate_accuracy(big_idx, targets):
    n_correct = (big_idx==targets).sum().item()
    return n_correct

# %%
# For validation
def validate(model, data_loader):
    model.eval()
    n_correct = 0 
    nb_test_steps = 0
    nb_test_examples = 0
    test_loss = 0
    y_pred = []
    y_true = []

    with torch.no_grad():
        for _, data in enumerate(data_loader, 0):
            input_ids = data['input_ids'].to(device)
            mask = data['attn_mask'].to(device)
            labels = data['label'].to(device)

            outputs = model(input_ids, mask)
            loss = loss_function(outputs[0], labels)
            test_loss += loss.item()

            # gets labels with highest probabilities and their corresponding indices
            big_val, big_idx = torch.max(outputs[0].data, dim=1)
            n_correct += calculate_accuracy(big_idx, labels)

            preds = (big_idx + 1).cpu().tolist()
            gold = (labels + 1).cpu().tolist()
            y_pred.extend(preds)
            y_true.extend(gold)

            nb_test_steps += 1
            nb_test_examples += labels.size(0)
            
    epoch_loss = test_loss/nb_test_steps
    epoch_accu = (n_correct*100)/nb_test_examples
    print(f"Validation Loss: {epoch_loss}")
    print(f"Validation Accuracy: {epoch_accu}\n")
    
    return y_true, y_pred, epoch_accu

# %%
# Training loop
def train(epoch):
    # number of batches run by model
    nb_tr_steps = 0
    # number of training examples run by model
    nb_tr_examples = 0
    # number of examples classified correctly by model
    n_correct = 0
    tr_loss = 0
    model.train()

    for batch, data in enumerate(train_loader):
        input_ids = data['input_ids'].to(device)
        mask = data['attn_mask'].to(device)
        labels = data['label'].to(device)

        outputs = model(input_ids, mask)
        loss = loss_function(outputs[0], labels)
        tr_loss += loss.item()

        # gets labels with highest probabilities and their corresponding indices
        big_val, big_idx = torch.max(outputs[0].data, dim=1)
        n_correct += calculate_accuracy(big_idx, labels)

        nb_tr_steps += 1
        nb_tr_examples+=labels.size(0)
        
        if batch % SAVE_EVERY == 0:
            loss_step = tr_loss/nb_tr_steps
            accu_step = (n_correct*100)/nb_tr_examples 
            print("Batch {} of epoch {} complete.".format(batch, epoch+1))
            print(f"Training Loss: {loss_step}   Training Accuracy: {accu_step}")

            if not os.path.exists(CHECKPOINT_FOLDER):
              os.makedirs(CHECKPOINT_FOLDER)

            # Since a single epoch could take well over hours, we regularly save the model even during evaluation of training accuracy.
            torch.save(model.state_dict(), os.path.join(PROJECT_FOLDER, CHECKPOINT_FOLDER, CHECKPOINT_FILE))
            print("Saving checkpoint at", os.path.join(PROJECT_FOLDER, CHECKPOINT_FOLDER, CHECKPOINT_FILE))

        optimizer.zero_grad()
        loss.backward()
        # When using GPU
        optimizer.step()

    print('\n*****\n')
    print(f'The Total Accuracy for Epoch {epoch+1}: {(n_correct*100)/nb_tr_examples}')
    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = (n_correct*100)/nb_tr_examples
    print(f"Training Loss: {epoch_loss}")
    print(f"Training Accuracy: {epoch_accu}\n")

    # Evaluate model after training it on this epoch
    validate(model, val_loader)

    torch.save(model.state_dict(), os.path.join(PROJECT_FOLDER, CHECKPOINT_FOLDER, CHECKPOINT_FILE))
    model.save_pretrained(os.path.join(PROJECT_FOLDER, MODEL_FOLDER, str(epoch+1)))
    print("Saving checkpoint at ", os.path.join(PROJECT_FOLDER, CHECKPOINT_FOLDER, CHECKPOINT_FILE))
    print("Saving model at ", os.path.join(PROJECT_FOLDER, MODEL_FOLDER, str(epoch+1)), '\n\n================================================\n')

    return

# %%
# # Training without weighted loss
# for epoch in range(EPOCHS):
#     train(epoch)
# Out:
# Batch 0 of epoch 1 complete.
# Training Loss: 1.754623532295227   Training Accuracy: 9.375
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 1 complete.
# Training Loss: 0.9618283035141406   Training Accuracy: 68.28589108910892
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 1 complete.
# Training Loss: 0.8432419965812816   Training Accuracy: 71.51741293532338
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 1 complete.
# Training Loss: 0.7857411857261214   Training Accuracy: 73.14161129568106
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 1 complete.
# Training Loss: 0.7539933294875366   Training Accuracy: 73.87001246882792
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 1 complete.
# Training Loss: 0.7263684099662804   Training Accuracy: 74.7317864271457
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 1 complete.
# Training Loss: 0.7125702636957962   Training Accuracy: 75.02079866888519
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 1 complete.
# Training Loss: 0.6964805500100921   Training Accuracy: 75.47699714693296
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 1 complete.
# Training Loss: 0.6810311771994375   Training Accuracy: 75.88171036204744
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 1 complete.
# Training Loss: 0.6709090680148573   Training Accuracy: 76.05785238623751
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 1 complete.
# Training Loss: 0.6654642905954358   Training Accuracy: 76.18006993006993
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 1 complete.
# Training Loss: 0.6591511383233126   Training Accuracy: 76.35672116257948
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 1 complete.
# Training Loss: 0.6537791738452562   Training Accuracy: 76.4701290591174
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 1 complete.
# Training Loss: 0.6481458461806923   Training Accuracy: 76.63576095311299
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 1 complete.
# Training Loss: 0.6443154310261157   Training Accuracy: 76.66399000713776
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 1 complete.
# Training Loss: 0.6411561919878833   Training Accuracy: 76.7550799467022
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 1 complete.
# Training Loss: 0.6370131977642424   Training Accuracy: 76.86797314178638
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 1 complete.
# Training Loss: 0.6352441595940643   Training Accuracy: 76.86287477954144
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 1 complete.
# Training Loss: 0.633159849525888   Training Accuracy: 76.92254303164908
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 1 complete.
# Training Loss: 0.6293904980912075   Training Accuracy: 77.06470278800631
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 1 complete.
# Training Loss: 0.627924673665112   Training Accuracy: 77.08958020989505
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 1 complete.
# Training Loss: 0.6256730007889837   Training Accuracy: 77.17753450737744
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 1 complete.
# Training Loss: 0.6247339733875865   Training Accuracy: 77.20070422535211
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 1 complete.
# Training Loss: 0.6219592782620604   Training Accuracy: 77.31149500217296
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 1 complete.
# Training Loss: 0.6205533740422171   Training Accuracy: 77.3649000416493
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 1 complete.
# Training Loss: 0.6190097225351078   Training Accuracy: 77.4265293882447
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 1 complete.
# Training Loss: 0.6172373027285444   Training Accuracy: 77.48822568242983
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 1 complete.
# Training Loss: 0.6150019669843929   Training Accuracy: 77.54072565716402
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 1 complete.
# Training Loss: 0.6129677986479453   Training Accuracy: 77.61067475901464
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 1 complete.
# Training Loss: 0.611179305433775   Training Accuracy: 77.67364701826956
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 1 complete.
# Training Loss: 0.6094473269890642   Training Accuracy: 77.72096801066311
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 1 complete.
# Training Loss: 0.6080325037596572   Training Accuracy: 77.78639954853273
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 1 complete.
# Training Loss: 0.6068844437710906   Training Accuracy: 77.80576382380507
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 1 complete.
# Training Loss: 0.6062769259026252   Training Accuracy: 77.80218115722508
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 1 complete.
# Training Loss: 0.6054855056350212   Training Accuracy: 77.83096883269627
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 1 complete.
# Training Loss: 0.604788761357177   Training Accuracy: 77.8554341616681
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 1 complete.
# Training Loss: 0.6039170623818757   Training Accuracy: 77.89329352957512
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 1 complete.
# Training Loss: 0.60254960829456   Training Accuracy: 77.9274182653337
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 1 complete.
# Training Loss: 0.6010406132561067   Training Accuracy: 77.95974743488556
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 1 complete.
# Training Loss: 0.6001162413709196   Training Accuracy: 77.99362342988977
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 1 complete.
# Training Loss: 0.598503799784544   Training Accuracy: 78.04298925268682
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 1 complete.
# Training Loss: 0.5968980152369766   Training Accuracy: 78.08461350890026
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 1 complete.
# Training Loss: 0.5955690248640796   Training Accuracy: 78.13690192811235
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 1: 78.16324296712519
# Training Loss: 0.5947314957515564
# Training Accuracy: 78.16324296712519
#
# Validation Loss: 0.5619781662776969
# Validation Accuracy: 79.2409460080707
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V2/1
#
# ================================================
#
# Batch 0 of epoch 2 complete.
# Training Loss: 0.4734230935573578   Training Accuracy: 78.125
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 2 complete.
# Training Loss: 0.502982950299093   Training Accuracy: 80.90965346534654
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 2 complete.
# Training Loss: 0.48506827622800325   Training Accuracy: 81.57649253731343
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 2 complete.
# Training Loss: 0.48908346747837195   Training Accuracy: 81.47840531561462
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 2 complete.
# Training Loss: 0.4865173853915231   Training Accuracy: 81.47599750623442
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 2 complete.
# Training Loss: 0.4851540067417179   Training Accuracy: 81.5119760479042
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 2 complete.
# Training Loss: 0.48779521386655117   Training Accuracy: 81.57757903494176
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 2 complete.
# Training Loss: 0.48933798659289957   Training Accuracy: 81.58434379457917
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 2 complete.
# Training Loss: 0.4915053453784757   Training Accuracy: 81.56210986267166
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 2 complete.
# Training Loss: 0.488980252225444   Training Accuracy: 81.67660932297447
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 2 complete.
# Training Loss: 0.4902856920982574   Training Accuracy: 81.60589410589411
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 2 complete.
# Training Loss: 0.49144011392824005   Training Accuracy: 81.59059945504087
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 2 complete.
# Training Loss: 0.4935361810779194   Training Accuracy: 81.44514987510408
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 2 complete.
# Training Loss: 0.49413977024488315   Training Accuracy: 81.4685818601076
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 2 complete.
# Training Loss: 0.4953736593357841   Training Accuracy: 81.42621341898644
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 2 complete.
# Training Loss: 0.4954509144868555   Training Accuracy: 81.41030979347101
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 2 complete.
# Training Loss: 0.49498420204038845   Training Accuracy: 81.44323860087445
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 2 complete.
# Training Loss: 0.49557416540061916   Training Accuracy: 81.43371546149324
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 2 complete.
# Training Loss: 0.49734806474598164   Training Accuracy: 81.34716823986675
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 2 complete.
# Training Loss: 0.49769127882746633   Training Accuracy: 81.32561809573909
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 2 complete.
# Training Loss: 0.49849263440886477   Training Accuracy: 81.30622188905548
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 2 complete.
# Training Loss: 0.4982896523318763   Training Accuracy: 81.31098286530224
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 2 complete.
# Training Loss: 0.4983551482357312   Training Accuracy: 81.2897546569741
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 2 complete.
# Training Loss: 0.4984045982496835   Training Accuracy: 81.26629726205998
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 2 complete.
# Training Loss: 0.49774406945603633   Training Accuracy: 81.29685547688463
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 2 complete.
# Training Loss: 0.49733577947207136   Training Accuracy: 81.312475009996
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 2 complete.
# Training Loss: 0.49673581827161223   Training Accuracy: 81.31968473663976
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 2 complete.
# Training Loss: 0.49659816947514285   Training Accuracy: 81.31247686042207
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 2 complete.
# Training Loss: 0.4973597790605679   Training Accuracy: 81.267850767583
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 2 complete.
# Training Loss: 0.49698013817953757   Training Accuracy: 81.27046708031713
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 2 complete.
# Training Loss: 0.49736876939434244   Training Accuracy: 81.26249583472176
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 2 complete.
# Training Loss: 0.49695687910907693   Training Accuracy: 81.27317800709449
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 2 complete.
# Training Loss: 0.4972362996628045   Training Accuracy: 81.25292877225867
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 2 complete.
# Training Loss: 0.49721412034296186   Training Accuracy: 81.26041351105725
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 2 complete.
# Training Loss: 0.4969463724138035   Training Accuracy: 81.27756542193472
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 2 complete.
# Training Loss: 0.49753190382519163   Training Accuracy: 81.23839617252213
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 2 complete.
# Training Loss: 0.49753291225456525   Training Accuracy: 81.24132185504027
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 2 complete.
# Training Loss: 0.49698651224672713   Training Accuracy: 81.24577816806269
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 2 complete.
# Training Loss: 0.4975708233929094   Training Accuracy: 81.24013417521705
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 2 complete.
# Training Loss: 0.4975444211528351   Training Accuracy: 81.25240322994104
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 2 complete.
# Training Loss: 0.49760535496811487   Training Accuracy: 81.2601537115721
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 2 complete.
# Training Loss: 0.498291154706138   Training Accuracy: 81.23475981467935
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 2 complete.
# Training Loss: 0.4979398730921479   Training Accuracy: 81.2633896691264
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 2: 81.2712080855256
# Training Loss: 0.4980993414840881
# Training Accuracy: 81.2712080855256
#
# Validation Loss: 0.5497984566963187
# Validation Accuracy: 79.47080758032385
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V2/2
#
# ================================================
#
# Batch 0 of epoch 3 complete.
# Training Loss: 0.4646671712398529   Training Accuracy: 87.5
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 3 complete.
# Training Loss: 0.43683937014919694   Training Accuracy: 83.3230198019802
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 3 complete.
# Training Loss: 0.4382414885273027   Training Accuracy: 83.36442786069652
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 3 complete.
# Training Loss: 0.43338035769834865   Training Accuracy: 83.74169435215947
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 3 complete.
# Training Loss: 0.42334724866095325   Training Accuracy: 84.02431421446384
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 3 complete.
# Training Loss: 0.4241347646790588   Training Accuracy: 84.00698602794411
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 3 complete.
# Training Loss: 0.42414520754046525   Training Accuracy: 84.00062396006656
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 3 complete.
# Training Loss: 0.42489245492492017   Training Accuracy: 83.96932952924394
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 3 complete.
# Training Loss: 0.4216842519749565   Training Accuracy: 84.12141073657928
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 3 complete.
# Training Loss: 0.4230522594676166   Training Accuracy: 84.08712541620422
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 3 complete.
# Training Loss: 0.42559616173153275   Training Accuracy: 83.97227772227772
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 3 complete.
# Training Loss: 0.4233753910926014   Training Accuracy: 84.00317892824705
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 3 complete.
# Training Loss: 0.4225744999554334   Training Accuracy: 84.02373022481265
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 3 complete.
# Training Loss: 0.4245707906788354   Training Accuracy: 83.96906225980015
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 3 complete.
# Training Loss: 0.42275217132939347   Training Accuracy: 84.01811206281228
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 3 complete.
# Training Loss: 0.4225986295644638   Training Accuracy: 84.0169053964024
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 3 complete.
# Training Loss: 0.4228206424229894   Training Accuracy: 83.98461898813241
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 3 complete.
# Training Loss: 0.42288933131079476   Training Accuracy: 83.99838330393887
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 3 complete.
# Training Loss: 0.4232518980150286   Training Accuracy: 83.99500277623542
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 3 complete.
# Training Loss: 0.42463997003280884   Training Accuracy: 83.97060757496055
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 3 complete.
# Training Loss: 0.4262889791866471   Training Accuracy: 83.89086706646677
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 3 complete.
# Training Loss: 0.42638741937181823   Training Accuracy: 83.89159923845787
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 3 complete.
# Training Loss: 0.4258020851948975   Training Accuracy: 83.92917991821899
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 3 complete.
# Training Loss: 0.42645210760772256   Training Accuracy: 83.9159604519774
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 3 complete.
# Training Loss: 0.4266969571072377   Training Accuracy: 83.9103498542274
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 3 complete.
# Training Loss: 0.42716435545899784   Training Accuracy: 83.90018992403039
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 3 complete.
# Training Loss: 0.42757194130890924   Training Accuracy: 83.90883314109958
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 3 complete.
# Training Loss: 0.4262995758528005   Training Accuracy: 83.94807478711589
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 3 complete.
# Training Loss: 0.4268571551688353   Training Accuracy: 83.93988754016422
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 3 complete.
# Training Loss: 0.42708060937949355   Training Accuracy: 83.95919510513616
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 3 complete.
# Training Loss: 0.4268365518792952   Training Accuracy: 83.97096801066311
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 3 complete.
# Training Loss: 0.42684877433437796   Training Accuracy: 83.97795066107707
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 3 complete.
# Training Loss: 0.42727338471233156   Training Accuracy: 83.95130427991253
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 3 complete.
# Training Loss: 0.42655573285590226   Training Accuracy: 83.9717131172372
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 3 complete.
# Training Loss: 0.4262442937785126   Training Accuracy: 83.98357100852691
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 3 complete.
# Training Loss: 0.42655999485219215   Training Accuracy: 83.96083261925165
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 3 complete.
# Training Loss: 0.42600131955569864   Training Accuracy: 83.98274784782005
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 3 complete.
# Training Loss: 0.4250764024842272   Training Accuracy: 84.00854498784112
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 3 complete.
# Training Loss: 0.42544138098321316   Training Accuracy: 84.01654169955275
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 3 complete.
# Training Loss: 0.4253994293837509   Training Accuracy: 84.01291335554986
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 3 complete.
# Training Loss: 0.42523845434710256   Training Accuracy: 84.01649587603099
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 3 complete.
# Training Loss: 0.4251188576126994   Training Accuracy: 84.02904779322117
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 3 complete.
# Training Loss: 0.4250668144011832   Training Accuracy: 84.03505117829089
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 3: 84.031816689167
# Training Loss: 0.42492039537502174
# Training Accuracy: 84.031816689167
#
# Validation Loss: 0.5918766453350875
# Validation Accuracy: 79.72110129233283
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V2/3
#
# ================================================
#
# Batch 0 of epoch 4 complete.
# Training Loss: 0.39014071226119995   Training Accuracy: 84.375
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 4 complete.
# Training Loss: 0.3270065411925316   Training Accuracy: 88.0569306930693
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 4 complete.
# Training Loss: 0.33212663272201126   Training Accuracy: 87.91977611940298
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 4 complete.
# Training Loss: 0.3338781927535898   Training Accuracy: 87.76993355481727
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 4 complete.
# Training Loss: 0.33994261033257045   Training Accuracy: 87.58572319201996
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 4 complete.
# Training Loss: 0.3394439645527961   Training Accuracy: 87.6122754491018
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 4 complete.
# Training Loss: 0.34284917482743643   Training Accuracy: 87.4896006655574
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 4 complete.
# Training Loss: 0.34215195118296843   Training Accuracy: 87.5
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 4 complete.
# Training Loss: 0.343301036761383   Training Accuracy: 87.37125468164794
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 4 complete.
# Training Loss: 0.3435207688261018   Training Accuracy: 87.34739178690344
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 4 complete.
# Training Loss: 0.34316237082148526   Training Accuracy: 87.36888111888112
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 4 complete.
# Training Loss: 0.3439771891635023   Training Accuracy: 87.34956857402362
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 4 complete.
# Training Loss: 0.34474883014824764   Training Accuracy: 87.31005412156536
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 4 complete.
# Training Loss: 0.3442310685210279   Training Accuracy: 87.32465411222137
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 4 complete.
# Training Loss: 0.3455899023077983   Training Accuracy: 87.2323340471092
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 4 complete.
# Training Loss: 0.3452321171591792   Training Accuracy: 87.25224850099933
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 4 complete.
# Training Loss: 0.3463215924506259   Training Accuracy: 87.19940662086196
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 4 complete.
# Training Loss: 0.34659750754783464   Training Accuracy: 87.17298647854203
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 4 complete.
# Training Loss: 0.3474345127826992   Training Accuracy: 87.13041365907829
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 4 complete.
# Training Loss: 0.348784561837773   Training Accuracy: 87.09067596002104
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 4 complete.
# Training Loss: 0.34826544206077487   Training Accuracy: 87.12050224887557
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 4 complete.
# Training Loss: 0.3479624138254032   Training Accuracy: 87.12220371251784
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 4 complete.
# Training Loss: 0.3480505755662864   Training Accuracy: 87.12375056792366
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 4 complete.
# Training Loss: 0.34912002006013826   Training Accuracy: 87.08441981747066
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 4 complete.
# Training Loss: 0.3493164044706735   Training Accuracy: 87.07179300291546
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 4 complete.
# Training Loss: 0.34941306439448433   Training Accuracy: 87.05892642942823
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 4 complete.
# Training Loss: 0.34972166114188485   Training Accuracy: 87.0518550557478
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 4 complete.
# Training Loss: 0.3500216589983372   Training Accuracy: 87.04067937800815
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 4 complete.
# Training Loss: 0.35020869801679455   Training Accuracy: 87.02137629418066
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 4 complete.
# Training Loss: 0.3502737942727341   Training Accuracy: 87.0335660117201
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 4 complete.
# Training Loss: 0.3502436304034809   Training Accuracy: 87.03661279573475
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 4 complete.
# Training Loss: 0.3502786524163758   Training Accuracy: 87.04248629474363
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 4 complete.
# Training Loss: 0.3500370861324099   Training Accuracy: 87.04018275538894
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 4 complete.
# Training Loss: 0.35117782531512104   Training Accuracy: 87.01340502877916
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 4 complete.
# Training Loss: 0.35092430311054984   Training Accuracy: 87.03506321670098
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 4 complete.
# Training Loss: 0.35144466641301836   Training Accuracy: 87.01620965438447
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 4 complete.
# Training Loss: 0.3516351760139286   Training Accuracy: 87.01923076923077
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 4 complete.
# Training Loss: 0.3519632930952177   Training Accuracy: 87.02124425830857
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 4 complete.
# Training Loss: 0.35226359812190455   Training Accuracy: 87.0083530649829
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 4 complete.
# Training Loss: 0.35218446713893026   Training Accuracy: 87.00413355549858
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 4 complete.
# Training Loss: 0.35228333900147485   Training Accuracy: 86.98528492876781
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 4 complete.
# Training Loss: 0.35211586460863575   Training Accuracy: 87.00164594001463
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 4 complete.
# Training Loss: 0.3527716510104256   Training Accuracy: 86.96962032849322
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 4: 86.97704965884628
# Training Loss: 0.35267460535748135
# Training Accuracy: 86.97704965884628
#
# Validation Loss: 0.6259224796850308
# Validation Accuracy: 79.21029779843694
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V2/4
#
# ================================================

# %%
# Training with weighted loss
for epoch in range(EPOCHS):
    train(epoch)
# Out:
# Batch 0 of epoch 1 complete.
# Training Loss: 1.7537753582000732   Training Accuracy: 0.0
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 1 complete.
# Training Loss: 1.5132590898192755   Training Accuracy: 45.88490099009901
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 1 complete.
# Training Loss: 1.3825425769559188   Training Accuracy: 54.57089552238806
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 1 complete.
# Training Loss: 1.3075979821309696   Training Accuracy: 58.409468438538205
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 1 complete.
# Training Loss: 1.2695915419561905   Training Accuracy: 59.77244389027432
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 1 complete.
# Training Loss: 1.2476821829696854   Training Accuracy: 61.13398203592814
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 1 complete.
# Training Loss: 1.2275544315725317   Training Accuracy: 61.917637271214645
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 1 complete.
# Training Loss: 1.210185926923058   Training Accuracy: 62.727353780313834
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 1 complete.
# Training Loss: 1.2063434558563613   Training Accuracy: 62.83161672908864
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 1 complete.
# Training Loss: 1.190752131163611   Training Accuracy: 63.54744728079911
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 1 complete.
# Training Loss: 1.1828158467442362   Training Accuracy: 63.66446053946054
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 1 complete.
# Training Loss: 1.1755058454665999   Training Accuracy: 63.91064940962761
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 1 complete.
# Training Loss: 1.1696151924272262   Training Accuracy: 64.25114487926727
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 1 complete.
# Training Loss: 1.1634859607184878   Training Accuracy: 64.51047271329746
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 1 complete.
# Training Loss: 1.1581935700903954   Training Accuracy: 64.87107423269093
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 1 complete.
# Training Loss: 1.1520916122265612   Training Accuracy: 65.04830113257827
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 1 complete.
# Training Loss: 1.1469376418904764   Training Accuracy: 65.18582136164898
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 1 complete.
# Training Loss: 1.1416546042213576   Training Accuracy: 65.52028218694885
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 1 complete.
# Training Loss: 1.1364815210978367   Training Accuracy: 65.7794280955025
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 1 complete.
# Training Loss: 1.1340264192322316   Training Accuracy: 65.9751446607049
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 1 complete.
# Training Loss: 1.1299705547669243   Training Accuracy: 66.18409545227387
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 1 complete.
# Training Loss: 1.1252169981279696   Training Accuracy: 66.35828177058544
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 1 complete.
# Training Loss: 1.1214730027641615   Training Accuracy: 66.53083825533848
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 1 complete.
# Training Loss: 1.1176283259797957   Training Accuracy: 66.62456540634507
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 1 complete.
# Training Loss: 1.1144694213021153   Training Accuracy: 66.74692836318201
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 1 complete.
# Training Loss: 1.109398277746778   Training Accuracy: 66.86950219912035
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 1 complete.
# Training Loss: 1.1068443327809883   Training Accuracy: 67.02229911572472
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 1 complete.
# Training Loss: 1.1023142369576446   Training Accuracy: 67.20311921510552
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 1 complete.
# Training Loss: 1.1006837524034772   Training Accuracy: 67.26950196358443
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 1 complete.
# Training Loss: 1.0972979461394767   Training Accuracy: 67.30437780075836
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 1 complete.
# Training Loss: 1.0952535502833551   Training Accuracy: 67.32443352215928
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 1 complete.
# Training Loss: 1.0920927464981227   Training Accuracy: 67.4852870041922
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 1 complete.
# Training Loss: 1.0902226076242292   Training Accuracy: 67.53065448297407
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 1 complete.
# Training Loss: 1.0896586352173252   Training Accuracy: 67.51931232959708
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 1 complete.
# Training Loss: 1.088333258345631   Training Accuracy: 67.58398265216113
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 1 complete.
# Training Loss: 1.086434488856973   Training Accuracy: 67.67887746358183
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 1 complete.
# Training Loss: 1.0844595482434805   Training Accuracy: 67.75982366009441
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 1 complete.
# Training Loss: 1.0834658300351594   Training Accuracy: 67.8338624696028
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 1 complete.
# Training Loss: 1.0809839300123274   Training Accuracy: 67.93771375953696
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 1 complete.
# Training Loss: 1.0787683661642273   Training Accuracy: 68.04425147398103
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 1 complete.
# Training Loss: 1.0768844437164178   Training Accuracy: 68.11578355411147
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 1 complete.
# Training Loss: 1.0752991060168824   Training Accuracy: 68.17544501341136
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 1 complete.
# Training Loss: 1.0734629450568527   Training Accuracy: 68.19730421328255
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 1: 68.25409566898968
# Training Loss: 1.0723845718509817
# Training Accuracy: 68.25409566898968
#
# Validation Loss: 0.9893574257399521
# Validation Accuracy: 70.78204014915462
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V3/1
#
# ================================================
#
# Batch 0 of epoch 2 complete.
# Training Loss: 0.8366026282310486   Training Accuracy: 71.875
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 2 complete.
# Training Loss: 0.8903373400173565   Training Accuracy: 72.4009900990099
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 2 complete.
# Training Loss: 0.900616972748913   Training Accuracy: 72.4657960199005
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 2 complete.
# Training Loss: 0.9101488791232886   Training Accuracy: 72.44601328903654
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 2 complete.
# Training Loss: 0.9064558127574492   Training Accuracy: 72.85692019950125
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 2 complete.
# Training Loss: 0.9064320905241899   Training Accuracy: 72.96032934131736
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 2 complete.
# Training Loss: 0.9068446764335061   Training Accuracy: 72.68094841930116
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 2 complete.
# Training Loss: 0.9084234198132868   Training Accuracy: 72.28958630527818
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 2 complete.
# Training Loss: 0.9049685041928262   Training Accuracy: 72.7020911360799
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 2 complete.
# Training Loss: 0.9071873467783552   Training Accuracy: 72.73515538290788
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 2 complete.
# Training Loss: 0.9051968540761854   Training Accuracy: 72.78658841158841
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 2 complete.
# Training Loss: 0.9089156880798825   Training Accuracy: 72.69811534968211
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 2 complete.
# Training Loss: 0.910084660206111   Training Accuracy: 72.81692339716902
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 2 complete.
# Training Loss: 0.9107902220219122   Training Accuracy: 72.78535741737126
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 2 complete.
# Training Loss: 0.9092903637741396   Training Accuracy: 72.88766952177016
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 2 complete.
# Training Loss: 0.9087650252929296   Training Accuracy: 72.89515323117921
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 2 complete.
# Training Loss: 0.9091574189664422   Training Accuracy: 72.8841349156777
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 2 complete.
# Training Loss: 0.910050279389123   Training Accuracy: 72.79908877131099
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 2 complete.
# Training Loss: 0.9086600727567667   Training Accuracy: 72.87444475291505
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 2 complete.
# Training Loss: 0.9078732510888533   Training Accuracy: 72.92214623882167
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 2 complete.
# Training Loss: 0.9086088581063758   Training Accuracy: 72.89636431784108
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 2 complete.
# Training Loss: 0.9098780301001911   Training Accuracy: 72.91914564493098
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 2 complete.
# Training Loss: 0.9089920696942495   Training Accuracy: 73.00658791458427
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 2 complete.
# Training Loss: 0.9093645761993231   Training Accuracy: 73.01988265971316
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 2 complete.
# Training Loss: 0.911700869229673   Training Accuracy: 72.95007288629738
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 2 complete.
# Training Loss: 0.9125279080791504   Training Accuracy: 72.93707516993203
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 2 complete.
# Training Loss: 0.911242164886259   Training Accuracy: 72.94910611303345
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 2 complete.
# Training Loss: 0.9108975270817519   Training Accuracy: 72.9313217326916
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 2 complete.
# Training Loss: 0.9116287175905105   Training Accuracy: 72.9471617279543
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 2 complete.
# Training Loss: 0.9119654460143978   Training Accuracy: 72.8595742847294
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 2 complete.
# Training Loss: 0.9122597287989028   Training Accuracy: 72.83405531489504
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 2 complete.
# Training Loss: 0.9131008932491304   Training Accuracy: 72.88878587552402
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 2 complete.
# Training Loss: 0.9139401803013684   Training Accuracy: 72.83661355826304
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 2 complete.
# Training Loss: 0.9140309492987743   Training Accuracy: 72.86428355043927
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 2 complete.
# Training Loss: 0.9140229062959048   Training Accuracy: 72.88940752719789
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 2 complete.
# Training Loss: 0.9145080145087728   Training Accuracy: 72.89881462439303
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 2 complete.
# Training Loss: 0.9142880091416243   Training Accuracy: 72.93113024159956
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 2 complete.
# Training Loss: 0.914282897925641   Training Accuracy: 72.9363685490408
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 2 complete.
# Training Loss: 0.9140311525906741   Training Accuracy: 72.92899894764535
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 2 complete.
# Training Loss: 0.9144925760079946   Training Accuracy: 72.93802871058703
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 2 complete.
# Training Loss: 0.9129772354992769   Training Accuracy: 72.98722194451388
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 2 complete.
# Training Loss: 0.9129353431965251   Training Accuracy: 73.01877590831505
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 2 complete.
# Training Loss: 0.9135859542462236   Training Accuracy: 72.99898833611044
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 2: 72.9930309774875
# Training Loss: 0.9132168009518853
# Training Accuracy: 72.9930309774875
#
# Validation Loss: 0.993399887887481
# Validation Accuracy: 70.62369106604689
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V3/2
#
# ================================================
#
# Batch 0 of epoch 3 complete.
# Training Loss: 0.6903647184371948   Training Accuracy: 84.375
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 3 complete.
# Training Loss: 0.744931557095877   Training Accuracy: 77.81559405940594
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 3 complete.
# Training Loss: 0.7444094259347489   Training Accuracy: 78.20273631840796
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 3 complete.
# Training Loss: 0.7552520309967852   Training Accuracy: 77.50207641196013
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 3 complete.
# Training Loss: 0.7536084596950217   Training Accuracy: 77.0573566084788
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 3 complete.
# Training Loss: 0.7618358758633246   Training Accuracy: 76.75274451097805
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 3 complete.
# Training Loss: 0.760263590665903   Training Accuracy: 76.65869384359401
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 3 complete.
# Training Loss: 0.7596822974515199   Training Accuracy: 76.47111269614835
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 3 complete.
# Training Loss: 0.7609682888648335   Training Accuracy: 76.50983146067416
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 3 complete.
# Training Loss: 0.7620217415124806   Training Accuracy: 76.31798002219756
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 3 complete.
# Training Loss: 0.7617516035026127   Training Accuracy: 76.41421078921078
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 3 complete.
# Training Loss: 0.7621368623992512   Training Accuracy: 76.46457765667574
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 3 complete.
# Training Loss: 0.7619039251048003   Training Accuracy: 76.47533305578685
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 3 complete.
# Training Loss: 0.7644385475547931   Training Accuracy: 76.3835511145273
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 3 complete.
# Training Loss: 0.768870161419507   Training Accuracy: 76.21564953604569
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 3 complete.
# Training Loss: 0.7673840744149121   Training Accuracy: 76.32828114590274
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 3 complete.
# Training Loss: 0.7683402671991177   Training Accuracy: 76.15747970018738
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 3 complete.
# Training Loss: 0.7703861798839244   Training Accuracy: 76.05636390358613
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 3 complete.
# Training Loss: 0.768924102029954   Training Accuracy: 75.98556357579123
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 3 complete.
# Training Loss: 0.7693365576203279   Training Accuracy: 75.96988427143609
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 3 complete.
# Training Loss: 0.768395603514802   Training Accuracy: 75.94327836081959
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 3 complete.
# Training Loss: 0.768620223466525   Training Accuracy: 75.98762494050452
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 3 complete.
# Training Loss: 0.7680681318396712   Training Accuracy: 75.92997501135848
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 3 complete.
# Training Loss: 0.7691527625456005   Training Accuracy: 75.89770751847023
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 3 complete.
# Training Loss: 0.767911808614133   Training Accuracy: 75.90587255310287
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 3 complete.
# Training Loss: 0.7678155564263266   Training Accuracy: 75.9296281487405
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 3 complete.
# Training Loss: 0.7682058151148228   Training Accuracy: 75.9767877739331
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 3 complete.
# Training Loss: 0.7689834581077739   Training Accuracy: 75.90244353942984
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 3 complete.
# Training Loss: 0.7687791900171292   Training Accuracy: 75.9014637629418
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 3 complete.
# Training Loss: 0.767180603497072   Training Accuracy: 75.95764391589107
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 3 complete.
# Training Loss: 0.7677368284096046   Training Accuracy: 75.91219593468844
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 3 complete.
# Training Loss: 0.7688574701528401   Training Accuracy: 75.89184940341825
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 3 complete.
# Training Loss: 0.7703436124710246   Training Accuracy: 75.8796079350203
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 3 complete.
# Training Loss: 0.7693868354166035   Training Accuracy: 75.88704180551348
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 3 complete.
# Training Loss: 0.7692464169150974   Training Accuracy: 75.8288003528374
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 3 complete.
# Training Loss: 0.7698583815164888   Training Accuracy: 75.75960439874322
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 3 complete.
# Training Loss: 0.7697272425979351   Training Accuracy: 75.75933768397667
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 3 complete.
# Training Loss: 0.7697840461704223   Training Accuracy: 75.76499594704134
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 3 complete.
# Training Loss: 0.7707914311151635   Training Accuracy: 75.77528939752696
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 3 complete.
# Training Loss: 0.7707002418900233   Training Accuracy: 75.7369905152525
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 3 complete.
# Training Loss: 0.7718401210691237   Training Accuracy: 75.72794301424643
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 3 complete.
# Training Loss: 0.7724014565337725   Training Accuracy: 75.69723847841989
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 3 complete.
# Training Loss: 0.7731855126597489   Training Accuracy: 75.68287312544632
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 3: 75.67920604225198
# Training Loss: 0.7731223602996873
# Training Accuracy: 75.67920604225198
#
# Validation Loss: 1.0518692367119726
# Validation Accuracy: 68.62134136997497
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V3/3
#
# ================================================
#
# Batch 0 of epoch 4 complete.
# Training Loss: 0.5891798734664917   Training Accuracy: 84.375
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 4 complete.
# Training Loss: 0.5957089597635931   Training Accuracy: 78.125
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 4 complete.
# Training Loss: 0.6144908706643688   Training Accuracy: 78.80907960199005
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 4 complete.
# Training Loss: 0.607830171173197   Training Accuracy: 79.12167774086379
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 4 complete.
# Training Loss: 0.600757484647104   Training Accuracy: 79.39526184538653
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 4 complete.
# Training Loss: 0.5946421467972373   Training Accuracy: 79.77794411177645
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 4 complete.
# Training Loss: 0.5972825659442067   Training Accuracy: 79.64850249584026
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 4 complete.
# Training Loss: 0.6029346761919462   Training Accuracy: 79.3509272467903
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 4 complete.
# Training Loss: 0.6016846150903964   Training Accuracy: 79.3227215980025
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 4 complete.
# Training Loss: 0.6032248309893031   Training Accuracy: 79.24528301886792
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 4 complete.
# Training Loss: 0.6055071395891649   Training Accuracy: 79.25824175824175
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 4 complete.
# Training Loss: 0.6104543001325861   Training Accuracy: 79.22343324250681
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 4 complete.
# Training Loss: 0.6090283652179743   Training Accuracy: 79.27508326394671
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 4 complete.
# Training Loss: 0.6116496186866658   Training Accuracy: 79.06898539584935
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 4 complete.
# Training Loss: 0.6133002516501805   Training Accuracy: 78.91907566024268
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 4 complete.
# Training Loss: 0.6137056285484405   Training Accuracy: 78.94112258494337
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 4 complete.
# Training Loss: 0.6154488628075169   Training Accuracy: 78.95651155527796
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 4 complete.
# Training Loss: 0.6142795261724916   Training Accuracy: 78.93151087595533
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 4 complete.
# Training Loss: 0.6168130278537698   Training Accuracy: 78.84855635757913
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 4 complete.
# Training Loss: 0.6174688934104058   Training Accuracy: 78.8483035244608
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 4 complete.
# Training Loss: 0.6188370833794276   Training Accuracy: 78.81684157921039
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 4 complete.
# Training Loss: 0.6175674832843134   Training Accuracy: 78.72144217039505
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 4 complete.
# Training Loss: 0.6160204716294205   Training Accuracy: 78.78663107678328
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 4 complete.
# Training Loss: 0.6158261029539498   Training Accuracy: 78.78232290308561
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 4 complete.
# Training Loss: 0.6159612473499174   Training Accuracy: 78.75754893794253
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 4 complete.
# Training Loss: 0.6166352075440843   Training Accuracy: 78.7797381047581
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 4 complete.
# Training Loss: 0.6180894110625361   Training Accuracy: 78.65604575163398
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 4 complete.
# Training Loss: 0.6176489459634136   Training Accuracy: 78.65605331358756
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 4 complete.
# Training Loss: 0.6178976038137702   Training Accuracy: 78.6727954302035
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 4 complete.
# Training Loss: 0.6188743601263248   Training Accuracy: 78.70992761116857
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 4 complete.
# Training Loss: 0.6185948823748411   Training Accuracy: 78.73625458180607
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 4 complete.
# Training Loss: 0.6193453462104266   Training Accuracy: 78.75181393099
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 4 complete.
# Training Loss: 0.6191345119999558   Training Accuracy: 78.76932989690722
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 4 complete.
# Training Loss: 0.6194553409371005   Training Accuracy: 78.75738412602242
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 4 complete.
# Training Loss: 0.6196103185388979   Training Accuracy: 78.74981623052044
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 4 complete.
# Training Loss: 0.6195090249397863   Training Accuracy: 78.733754641531
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 4 complete.
# Training Loss: 0.6202122919495257   Training Accuracy: 78.73420577617328
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 4 complete.
# Training Loss: 0.6208153575682955   Training Accuracy: 78.66623885436368
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 4 complete.
# Training Loss: 0.6209426369597428   Training Accuracy: 78.63226782425677
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 4 complete.
# Training Loss: 0.621177184936237   Training Accuracy: 78.62887721097155
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 4 complete.
# Training Loss: 0.6219205586791366   Training Accuracy: 78.60612971757061
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 4 complete.
# Training Loss: 0.6235933207616781   Training Accuracy: 78.56467934650085
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 4 complete.
# Training Loss: 0.6252348761605637   Training Accuracy: 78.51999523922875
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 4: 78.53541066150983
# Training Loss: 0.6249060863031006
# Training Accuracy: 78.53541066150983
#
# Validation Loss: 1.2267925754871243
# Validation Accuracy: 68.79501455789958
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V3/4
#
# ================================================

# %%
# Training with weighted loss (1-dist)
for epoch in range(EPOCHS):
    train(epoch)
# Out:
# Batch 0 of epoch 1 complete.
# Training Loss: 1.486339807510376   Training Accuracy: 46.875
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 1 complete.
# Training Loss: 1.2299827673647663   Training Accuracy: 69.46163366336634
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 1 complete.
# Training Loss: 1.1006911972268898   Training Accuracy: 71.93718905472637
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 1 complete.
# Training Loss: 1.0376355314373573   Training Accuracy: 73.04817275747509
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 1 complete.
# Training Loss: 1.0143284614098043   Training Accuracy: 73.31670822942644
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 1 complete.
# Training Loss: 0.9967816003901278   Training Accuracy: 73.56536926147704
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 1 complete.
# Training Loss: 0.9860388161537056   Training Accuracy: 73.63768718801997
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 1 complete.
# Training Loss: 0.9730942556249262   Training Accuracy: 73.88997860199714
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 1 complete.
# Training Loss: 0.9628932830248581   Training Accuracy: 74.15730337078652
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 1 complete.
# Training Loss: 0.9555089935478439   Training Accuracy: 74.30285793562707
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 1 complete.
# Training Loss: 0.9500633140543958   Training Accuracy: 74.32567432567433
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 1 complete.
# Training Loss: 0.9417766979561406   Training Accuracy: 74.55722070844686
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 1 complete.
# Training Loss: 0.9361391818394371   Training Accuracy: 74.60970024979184
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 1 complete.
# Training Loss: 0.9302606751009833   Training Accuracy: 74.65891621829363
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 1 complete.
# Training Loss: 0.9250778247636187   Training Accuracy: 74.68772305496074
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 1 complete.
# Training Loss: 0.9207198809854671   Training Accuracy: 74.81678880746169
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 1 complete.
# Training Loss: 0.915292450631134   Training Accuracy: 75.02147095565272
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 1 complete.
# Training Loss: 0.9103311809773027   Training Accuracy: 75.07716049382717
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 1 complete.
# Training Loss: 0.9055493996581523   Training Accuracy: 75.19607162687396
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 1 complete.
# Training Loss: 0.9021517223649624   Training Accuracy: 75.27123882167281
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 1 complete.
# Training Loss: 0.8982338532246928   Training Accuracy: 75.36544227886057
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 1 complete.
# Training Loss: 0.8953371757215003   Training Accuracy: 75.36738457877202
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 1 complete.
# Training Loss: 0.8942562582708391   Training Accuracy: 75.39612676056338
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 1 complete.
# Training Loss: 0.8907016034439199   Training Accuracy: 75.5201542807475
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 1 complete.
# Training Loss: 0.8878187671620267   Training Accuracy: 75.57397959183673
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 1 complete.
# Training Loss: 0.8842687645658213   Training Accuracy: 75.66848260695721
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 1 complete.
# Training Loss: 0.8818278981946331   Training Accuracy: 75.72207804690504
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 1 complete.
# Training Loss: 0.8791435250791079   Training Accuracy: 75.80988522769344
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 1 complete.
# Training Loss: 0.8778653059398136   Training Accuracy: 75.81109425205284
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 1 complete.
# Training Loss: 0.8760530073882711   Training Accuracy: 75.84238193726301
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 1 complete.
# Training Loss: 0.8749491774074557   Training Accuracy: 75.84555148283906
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 1 complete.
# Training Loss: 0.8734449673394779   Training Accuracy: 75.91099645275717
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 1 complete.
# Training Loss: 0.8727374398607792   Training Accuracy: 75.900109340831
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 1 complete.
# Training Loss: 0.8714755413767714   Training Accuracy: 75.96088306573766
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 1 complete.
# Training Loss: 0.8703726541028588   Training Accuracy: 75.9730593942958
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 1 complete.
# Training Loss: 0.8689275719172204   Training Accuracy: 76.01042559268781
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 1 complete.
# Training Loss: 0.8674210091492627   Training Accuracy: 76.05873368508747
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 1 complete.
# Training Loss: 0.8663494453272991   Training Accuracy: 76.06643474736558
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 1 complete.
# Training Loss: 0.8644829660818721   Training Accuracy: 76.11483820047356
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 1 complete.
# Training Loss: 0.8630210347005692   Training Accuracy: 76.13112022558319
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 1 complete.
# Training Loss: 0.8616713032338715   Training Accuracy: 76.19423269182704
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 1 complete.
# Training Loss: 0.859826039712739   Training Accuracy: 76.24893318702756
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 1 complete.
# Training Loss: 0.8584065203779058   Training Accuracy: 76.2868959771483
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 1: 76.3213777502098
# Training Loss: 0.8573779185367137
# Training Accuracy: 76.3213777502098
#
# Validation Loss: 0.8110021389777364
# Validation Accuracy: 77.4224855698013
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V4/1
#
# ================================================
#
# Batch 0 of epoch 2 complete.
# Training Loss: 0.8427011966705322   Training Accuracy: 75.0
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 2 complete.
# Training Loss: 0.7533900489901552   Training Accuracy: 78.86757425742574
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 2 complete.
# Training Loss: 0.7339300729742098   Training Accuracy: 79.4776119402985
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 2 complete.
# Training Loss: 0.7226755189341169   Training Accuracy: 79.640780730897
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 2 complete.
# Training Loss: 0.7187360632152034   Training Accuracy: 79.95635910224439
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 2 complete.
# Training Loss: 0.7191518739668908   Training Accuracy: 79.94011976047904
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 2 complete.
# Training Loss: 0.7195258802066429   Training Accuracy: 79.8304908485857
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 2 complete.
# Training Loss: 0.7235763205186106   Training Accuracy: 79.77888730385165
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 2 complete.
# Training Loss: 0.7184407376171498   Training Accuracy: 79.9703495630462
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 2 complete.
# Training Loss: 0.7198205539640391   Training Accuracy: 79.93548834628191
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 2 complete.
# Training Loss: 0.7205735177069634   Training Accuracy: 79.8076923076923
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 2 complete.
# Training Loss: 0.7206115585690082   Training Accuracy: 79.78542234332426
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 2 complete.
# Training Loss: 0.7218045993311816   Training Accuracy: 79.7070149875104
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 2 complete.
# Training Loss: 0.7233236576391128   Training Accuracy: 79.63105303612606
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 2 complete.
# Training Loss: 0.7225535555578486   Training Accuracy: 79.73099571734475
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 2 complete.
# Training Loss: 0.7256600096533887   Training Accuracy: 79.65314790139907
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 2 complete.
# Training Loss: 0.7268591872942887   Training Accuracy: 79.69628357276702
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 2 complete.
# Training Loss: 0.7275255569670216   Training Accuracy: 79.65351263962376
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 2 complete.
# Training Loss: 0.7259061161608645   Training Accuracy: 79.69530816213215
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 2 complete.
# Training Loss: 0.7270763751740583   Training Accuracy: 79.63407417148869
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 2 complete.
# Training Loss: 0.7291117716675577   Training Accuracy: 79.57896051974014
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 2 complete.
# Training Loss: 0.7287471070140955   Training Accuracy: 79.536530223703
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 2 complete.
# Training Loss: 0.7272680385824444   Training Accuracy: 79.56610631531122
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 2 complete.
# Training Loss: 0.7260264597706876   Training Accuracy: 79.55915906127771
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 2 complete.
# Training Loss: 0.7259942183689195   Training Accuracy: 79.50333194502291
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 2 complete.
# Training Loss: 0.7252593594091218   Training Accuracy: 79.56067572970812
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 2 complete.
# Training Loss: 0.725186373065958   Training Accuracy: 79.55233564013841
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 2 complete.
# Training Loss: 0.72493543742057   Training Accuracy: 79.56890966308775
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 2 complete.
# Training Loss: 0.7250372161932478   Training Accuracy: 79.56421813637986
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 2 complete.
# Training Loss: 0.7241409869183346   Training Accuracy: 79.5953981385729
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 2 complete.
# Training Loss: 0.7247227796889353   Training Accuracy: 79.53286404531822
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 2 complete.
# Training Loss: 0.7240003139520607   Training Accuracy: 79.56102870041921
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 2 complete.
# Training Loss: 0.724228057571591   Training Accuracy: 79.5151905654483
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 2 complete.
# Training Loss: 0.7233736310464547   Training Accuracy: 79.52135716449561
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 2 complete.
# Training Loss: 0.7224470284345464   Training Accuracy: 79.55013231402529
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 2 complete.
# Training Loss: 0.723325679256929   Training Accuracy: 79.53531133961725
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 2 complete.
# Training Loss: 0.7235166776498071   Training Accuracy: 79.52391696750902
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 2 complete.
# Training Loss: 0.7234455477994894   Training Accuracy: 79.52327073763847
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 2 complete.
# Training Loss: 0.7230329194670444   Training Accuracy: 79.54814522494081
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 2 complete.
# Training Loss: 0.7231105440619725   Training Accuracy: 79.53890028197898
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 2 complete.
# Training Loss: 0.7236494010231013   Training Accuracy: 79.51918270432392
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 2 complete.
# Training Loss: 0.7233859973363951   Training Accuracy: 79.53014508656425
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 2 complete.
# Training Loss: 0.7228445354862402   Training Accuracy: 79.56141394905974
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 2: 79.55704746962455
# Training Loss: 0.7225599673489892
# Training Accuracy: 79.55704746962455
#
# Validation Loss: 0.7861618413742072
# Validation Accuracy: 77.81069622516218
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V4/2
#
# ================================================
#
# Batch 0 of epoch 3 complete.
# Training Loss: 0.5132076740264893   Training Accuracy: 90.625
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 3 complete.
# Training Loss: 0.6051902540839544   Training Accuracy: 82.45668316831683
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 3 complete.
# Training Loss: 0.6136219993752626   Training Accuracy: 82.64925373134328
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 3 complete.
# Training Loss: 0.610646780543153   Training Accuracy: 82.87998338870432
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 3 complete.
# Training Loss: 0.6076666919370541   Training Accuracy: 83.0423940149626
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 3 complete.
# Training Loss: 0.6067004447985076   Training Accuracy: 82.77819361277444
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 3 complete.
# Training Loss: 0.604237603962719   Training Accuracy: 82.88789517470882
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 3 complete.
# Training Loss: 0.6055501618671009   Training Accuracy: 82.72111269614835
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 3 complete.
# Training Loss: 0.6065857994199245   Training Accuracy: 82.68960674157303
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 3 complete.
# Training Loss: 0.6051705834041293   Training Accuracy: 82.66509433962264
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 3 complete.
# Training Loss: 0.6057031296498768   Training Accuracy: 82.59552947052947
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 3 complete.
# Training Loss: 0.6039954357316124   Training Accuracy: 82.57549954586739
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 3 complete.
# Training Loss: 0.6041731690362927   Training Accuracy: 82.5718151540383
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 3 complete.
# Training Loss: 0.6043065828969165   Training Accuracy: 82.54707916986933
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 3 complete.
# Training Loss: 0.6038046091114257   Training Accuracy: 82.55933261955745
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 3 complete.
# Training Loss: 0.6030806186376295   Training Accuracy: 82.63865756162558
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 3 complete.
# Training Loss: 0.6028172851893248   Training Accuracy: 82.6299968769519
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 3 complete.
# Training Loss: 0.6039475464141068   Training Accuracy: 82.6003086419753
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 3 complete.
# Training Loss: 0.6054756858824095   Training Accuracy: 82.5530955024986
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 3 complete.
# Training Loss: 0.6068401688936195   Training Accuracy: 82.49276696475539
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 3 complete.
# Training Loss: 0.6060573518544301   Training Accuracy: 82.51499250374813
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 3 complete.
# Training Loss: 0.606727177262136   Training Accuracy: 82.46965730604474
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 3 complete.
# Training Loss: 0.6060959888230341   Training Accuracy: 82.50653112221717
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 3 complete.
# Training Loss: 0.6055885954868891   Training Accuracy: 82.50217296827466
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 3 complete.
# Training Loss: 0.6051759688693352   Training Accuracy: 82.50989171178675
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 3 complete.
# Training Loss: 0.6053280961222764   Training Accuracy: 82.49325269892043
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 3 complete.
# Training Loss: 0.6053274205582548   Training Accuracy: 82.49831795463284
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 3 complete.
# Training Loss: 0.606413759906307   Training Accuracy: 82.4729266938171
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 3 complete.
# Training Loss: 0.6064040275055866   Training Accuracy: 82.49732238486254
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 3 complete.
# Training Loss: 0.6062772787262432   Training Accuracy: 82.51895897966219
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 3 complete.
# Training Loss: 0.6073666586354747   Training Accuracy: 82.48917027657447
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 3 complete.
# Training Loss: 0.6062263726457708   Training Accuracy: 82.49657368590778
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 3 complete.
# Training Loss: 0.6071377788361666   Training Accuracy: 82.47422680412372
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 3 complete.
# Training Loss: 0.6068513048973563   Training Accuracy: 82.48258103604968
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 3 complete.
# Training Loss: 0.6073426288021063   Training Accuracy: 82.46839164951484
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 3 complete.
# Training Loss: 0.6071130896220716   Training Accuracy: 82.48714652956298
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 3 complete.
# Training Loss: 0.6071670371040773   Training Accuracy: 82.49444598722577
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 3 complete.
# Training Loss: 0.6072271178941796   Training Accuracy: 82.49966225344501
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 3 complete.
# Training Loss: 0.6074861054223201   Training Accuracy: 82.49062746645619
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 3 complete.
# Training Loss: 0.6078634639522473   Training Accuracy: 82.45481927710843
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 3 complete.
# Training Loss: 0.6071344365316222   Training Accuracy: 82.47781804548863
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 3 complete.
# Training Loss: 0.6072424746117805   Training Accuracy: 82.47150085345038
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 3 complete.
# Training Loss: 0.6078467409941617   Training Accuracy: 82.45432635086884
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 3: 82.44025249023971
# Training Loss: 0.6084454847695865
# Training Accuracy: 82.44025249023971
#
# Validation Loss: 0.8362451853121028
# Validation Accuracy: 77.04449098431833
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V4/3
#
# ================================================
#
# Batch 0 of epoch 4 complete.
# Training Loss: 0.7705549001693726   Training Accuracy: 81.25
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 100 of epoch 4 complete.
# Training Loss: 0.4940501395428535   Training Accuracy: 85.73638613861387
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 200 of epoch 4 complete.
# Training Loss: 0.48169762478094197   Training Accuracy: 85.83644278606965
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 300 of epoch 4 complete.
# Training Loss: 0.4800713560559425   Training Accuracy: 85.90116279069767
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 400 of epoch 4 complete.
# Training Loss: 0.4836719366268921   Training Accuracy: 85.88684538653366
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 500 of epoch 4 complete.
# Training Loss: 0.4825349474649229   Training Accuracy: 85.90319361277444
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 600 of epoch 4 complete.
# Training Loss: 0.48507753333166714   Training Accuracy: 85.84650582362728
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 700 of epoch 4 complete.
# Training Loss: 0.4880984639071364   Training Accuracy: 85.76587018544936
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 800 of epoch 4 complete.
# Training Loss: 0.4905433101247015   Training Accuracy: 85.74828339575531
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 900 of epoch 4 complete.
# Training Loss: 0.4890969709454975   Training Accuracy: 85.7831576026637
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1000 of epoch 4 complete.
# Training Loss: 0.4896263747395097   Training Accuracy: 85.65184815184816
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1100 of epoch 4 complete.
# Training Loss: 0.49074499799001225   Training Accuracy: 85.61534968210718
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1200 of epoch 4 complete.
# Training Loss: 0.48985581423817426   Training Accuracy: 85.64217318900916
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1300 of epoch 4 complete.
# Training Loss: 0.49047108755649554   Training Accuracy: 85.6912951575711
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1400 of epoch 4 complete.
# Training Loss: 0.49254140517887773   Training Accuracy: 85.62633832976445
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1500 of epoch 4 complete.
# Training Loss: 0.4928673358409505   Training Accuracy: 85.62624916722186
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1600 of epoch 4 complete.
# Training Loss: 0.4915001478690717   Training Accuracy: 85.65544971892567
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1700 of epoch 4 complete.
# Training Loss: 0.4910012755689728   Training Accuracy: 85.66100823045268
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1800 of epoch 4 complete.
# Training Loss: 0.4905347950934437   Training Accuracy: 85.6555385896724
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 1900 of epoch 4 complete.
# Training Loss: 0.4892562716211663   Training Accuracy: 85.67530247238295
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2000 of epoch 4 complete.
# Training Loss: 0.4893741809103502   Training Accuracy: 85.70402298850574
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2100 of epoch 4 complete.
# Training Loss: 0.4897347934143365   Training Accuracy: 85.68092574964302
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2200 of epoch 4 complete.
# Training Loss: 0.4910961206746827   Training Accuracy: 85.63579054975011
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2300 of epoch 4 complete.
# Training Loss: 0.4915190651650172   Training Accuracy: 85.62717296827466
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2400 of epoch 4 complete.
# Training Loss: 0.49026594169496845   Training Accuracy: 85.66482715535194
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2500 of epoch 4 complete.
# Training Loss: 0.4908591270333574   Training Accuracy: 85.64449220311876
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2600 of epoch 4 complete.
# Training Loss: 0.4921754518268155   Training Accuracy: 85.5896770472895
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2700 of epoch 4 complete.
# Training Loss: 0.49177963547587883   Training Accuracy: 85.60949648278415
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2800 of epoch 4 complete.
# Training Loss: 0.49163324988099005   Training Accuracy: 85.60781863620136
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 2900 of epoch 4 complete.
# Training Loss: 0.4924910530108947   Training Accuracy: 85.58794381247846
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3000 of epoch 4 complete.
# Training Loss: 0.4927334522767013   Training Accuracy: 85.6235421526158
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3100 of epoch 4 complete.
# Training Loss: 0.49377761438839746   Training Accuracy: 85.59436472105773
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3200 of epoch 4 complete.
# Training Loss: 0.49351110480206717   Training Accuracy: 85.60898937831928
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3300 of epoch 4 complete.
# Training Loss: 0.49226545236420177   Training Accuracy: 85.642608300515
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3400 of epoch 4 complete.
# Training Loss: 0.4922863712440656   Training Accuracy: 85.63198324022346
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3500 of epoch 4 complete.
# Training Loss: 0.493023114401812   Training Accuracy: 85.62732076549557
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3600 of epoch 4 complete.
# Training Loss: 0.49297061494880834   Training Accuracy: 85.6055609552902
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3700 of epoch 4 complete.
# Training Loss: 0.4926933942031004   Training Accuracy: 85.59510942988382
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3800 of epoch 4 complete.
# Training Loss: 0.4929060369330122   Training Accuracy: 85.58520784004209
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 3900 of epoch 4 complete.
# Training Loss: 0.4935645339115251   Training Accuracy: 85.56620097410921
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4000 of epoch 4 complete.
# Training Loss: 0.49354963812775027   Training Accuracy: 85.5668895276181
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4100 of epoch 4 complete.
# Training Loss: 0.49355357064906635   Training Accuracy: 85.54773226042428
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Batch 4200 of epoch 4 complete.
# Training Loss: 0.49378923054494567   Training Accuracy: 85.53469412044751
# Saving checkpoint at /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
#
# *****
#
# The Total Accuracy for Epoch 4: 85.56062319845294
# Training Loss: 0.49329562579850683
# Training Accuracy: 85.56062319845294
#
# Validation Loss: 0.9455179093417778
# Validation Accuracy: 74.7816315063595
#
# Saving checkpoint at  /content/drive/My Drive/BERT project/Checkpoint/checkpoint.dat
# Saving model at  /content/drive/My Drive/BERT project/Model_V4/4
#
# ================================================

# %%
# Evaluation on test set
for epoch in range(1, EPOCHS+1):
  model = BertForSequenceClassification.from_pretrained(os.path.join(PROJECT_FOLDER, MODEL_FOLDER, str(epoch))).cuda()
  print(f'Running validation on model trained on {epoch} epochs')

  validate(model, test_loader)
# Out:
# Running validation on model trained on 1 epochs
# Validation Loss: 0.5471496991326217
# Validation Accuracy: 79.90703138967639
#
# Running validation on model trained on 2 epochs
# Validation Loss: 0.5360850396328697
# Validation Accuracy: 80.1445610808878
#
# Running validation on model trained on 3 epochs
# Validation Loss: 0.574592362602357
# Validation Accuracy: 80.08837126146145
#
# Running validation on model trained on 4 epochs
# Validation Loss: 0.6106200944327937
# Validation Accuracy: 79.32214645110209

# %%
model = BertForSequenceClassification.from_pretrained(os.path.join(PROJECT_FOLDER, MODEL_FOLDER, '2')).cuda()
print(f'Running validation on model trained on 2 epochs')

y_true, y_pred, epoch_acc = validate(model, test_loader)
# Out:
# Running validation on model trained on 2 epochs
# Validation Loss: 0.9980481928275302
# Validation Accuracy: 70.70977958266289
